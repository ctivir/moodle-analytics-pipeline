# %% [markdown]
# # 1. Introduction
# Purpose: Interpret which features most influence grade predictions.
#
# - Importance of interpretability
# - Permutation vs. SHAP

# %%
import pandas as pd
import sys
sys.path.insert(0, "../src")

from importance import feature_importance_analysis

df = pd.read_csv("../data/processed/session_features.csv")
importance_df = feature_importance_analysis(df)
print(importance_df)
# Out:
#                    Feature  Importance
# 16           Quiz_Reviewed    0.158682
# 14          Quiz_Submitted    0.127350
# 4   Session_Start_Hour_STD    0.082459
# 15             Quiz_Viewed    0.069781
# 3     Avg_Time_Per_Session    0.066430
# 5      Session_Interval_CV    0.060757
# 9            Content_Views    0.050316
# 8             Module_Views    0.045084
# 2        Total_Time_Online    0.044877
# 7             Course_Views    0.042375
# 19        Files_Downloaded    0.041337
# 12           Messages_Sent    0.035875
# 1             Total_Clicks    0.034678
# 0             Num_Sessions    0.030512
# 13            Quiz_Started    0.027613
# 21          Meeting_Joined    0.026377
# 20          Files_Uploaded    0.025231
# 11             Forum_Views    0.014945
# 17   Assignments_Submitted    0.013789
# 10             Forum_Posts    0.001409
# 6    Max_Inactivity_Period    0.000123
# 18        Assignment_Views    0.000000

# %% [markdown]
# Top predictors: Quiz_Reviewed, Quiz_Submitted and Session_Start_Hour_STD
# Negative signals: Forum_Posts, Max_Inactivity_Period and Assignment_Views
