# %% [markdown]
# # 1. Introduction
#
# Purpose: Train and compare regression models to predict final grades.
# - Regression task setup
# - Model types: Linear, Ridge, Lasso, RF, GB

# %% [markdown]
# Model Comparison
#
# - R² scores
# - MSE values
# - Plot bar chart of performance

# %%
import sys
sys.path.insert(0, "../src")

import pandas as pd
from pathlib import Path
from regression import run_regression_models

REPORT_DIR = Path("../report").resolve()
file_path = "../data/processed/session_features.csv"

# Load dataset
df = pd.read_csv(file_path)

# Run regression
results = run_regression_models(df, REPORT_DIR)
display(results)
# Out:
# Best RF parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 300}
#                                   MSE        R2
# Linear Regression          338.901512  0.254928
# Ridge Regression           338.867149  0.255004
# Lasso Regression           366.100219  0.195132
# Decision Tree Regressor    540.015626 -0.187220
# Random Forest              285.494410  0.372343
# Gradient Boosting          295.323351  0.350734
# XGBoost                    343.830312  0.244092
# Random Forest (Optimized)  283.362442  0.377030
# LLM-ready dataset exported to: /Users/ctivir/projects/ml/ed_simulator/unchk/moodle-analytics-pipeline/report/shap/llm_ready_dataset.csv
#                                   MSE        R2
# Linear Regression          338.901512  0.254928
# Ridge Regression           338.867149  0.255004
# Lasso Regression           366.100219  0.195132
# Decision Tree Regressor    540.015626 -0.187220
# Random Forest              285.494410  0.372343
# Gradient Boosting          295.323351  0.350734
# XGBoost                    343.830312  0.244092
# Random Forest (Optimized)  283.362442  0.377030
