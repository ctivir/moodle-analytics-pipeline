# %% [markdown]
# # 1. Introduction
#
# Purpose: Train and compare regression models to predict final grades.
# - Regression task setup
# - Model types: Linear, Ridge, Lasso, RF, GB

# %% [markdown]
# Model Comparison
#
# - R² scores
# - MSE values
# - Plot bar chart of performance

# %%
import sys
sys.path.insert(0, "../src")

import pandas as pd
from pathlib import Path
from regression import run_regression_models

REPORT_DIR = Path("../report").resolve()
file_path = "../data/processed/session_features.csv"

# Load dataset
df = pd.read_csv(file_path)

# Run regression
results = run_regression_models(df, REPORT_DIR)
display(results)
