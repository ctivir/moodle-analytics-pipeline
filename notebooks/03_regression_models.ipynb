# %% [markdown]
# # 1. Introduction
#
# Purpose: Train and compare regression models to predict final grades.
# - Regression task setup
# - Model types: Linear, Ridge, Lasso, RF, GB

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parents[0]
sys.path.append(str(PROJECT_ROOT / "src"))

from regression import run_regression_models

df = pd.read_csv(PROJECT_ROOT / "data" / "processed" / "session_features.csv")
results = run_regression_models(df)
print(results)
# Out:
# {'Linear Regression': {'MSE': 338.90151193824937, 'R2': 0.2549279771977564}, 'Ridge Regression': {'MSE': 338.8671491681517, 'R2': 0.2550035234485811}, 'Lasso Regression': {'MSE': 366.10021920185494, 'R2': 0.19513185612824313}, 'Random Forest': {'MSE': 287.75267407958466, 'R2': 0.3673782518199693}, 'Gradient Boosting': {'MSE': 295.4926519855048, 'R2': 0.3503619777944367}}

# %% [markdown]
# Model Comparison
#
# - R² scores
# - MSE values
# - Plot bar chart of performance
