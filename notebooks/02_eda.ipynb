# %% [markdown]
# # 1. Introduction
#
# Purpose: Visualize engagement distributions, grade patterns, and feature relationships.
#
# - Motivation for EDA in LMS data
# - References to Romero & Ventura, Costa et al., Akçapınar et al.

# %%
import pandas as pd
import sys
sys.path.insert(0, "../src")

file_path = "../data/processed/session_features.csv"

from eda_plots import run_eda_plots

df = pd.read_csv(file_path)
run_eda_plots(df)
